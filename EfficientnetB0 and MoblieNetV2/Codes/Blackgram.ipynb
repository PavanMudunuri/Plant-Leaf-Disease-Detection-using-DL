# %%
`# ======================================================
# BLACKGRAM DATA PREPROCESSING SCRIPT
# ======================================================

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
import shutil
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# ======================================================
# STEP 1: PATH SETUP
# ======================================================
BASE_PATH = '/content/drive/MyDrive/CapStoneProjectDataSets'
INPUT_PATH = f'{BASE_PATH}/Blackgram'
OUTPUT_PATH = f'{BASE_PATH}/Blackgram_split'  # Preprocessed data folder

IMG_SIZE = (224, 224)
TEST_RATIO = 0.2

# ======================================================
# STEP 2: DELETE EXISTING PREPROCESSED DATA
# ======================================================
if os.path.exists(OUTPUT_PATH):
    shutil.rmtree(OUTPUT_PATH)
    print(f"🧹 Deleted existing folder: {OUTPUT_PATH}")
else:
    print(f"✅ No existing preprocessed folder found at: {OUTPUT_PATH}")

os.makedirs(f"{OUTPUT_PATH}/train", exist_ok=True)
os.makedirs(f"{OUTPUT_PATH}/test", exist_ok=True)

# ======================================================
# STEP 3: FETCH CLASSES
# ======================================================
classes = [d for d in os.listdir(INPUT_PATH)
           if os.path.isdir(os.path.join(INPUT_PATH, d))
           and d.lower() not in ['blackgram_split', 'preprocessed_data']]

print("📁 Found Classes:", classes)

# ======================================================
# STEP 4: SPLIT, RESIZE, SAVE
# ======================================================
for cls in classes:
    cls_path = os.path.join(INPUT_PATH, cls)
    images = [os.path.join(cls_path, f) for f in os.listdir(cls_path)
              if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    print(f"\n🧾 Processing Class: {cls} ({len(images)} images)")

    if len(images) == 0:
        print(f"⚠️ No images found in {cls}, skipping...")
        continue

    train_imgs, test_imgs = train_test_split(images, test_size=TEST_RATIO, random_state=42)

    for split_name, split_data in zip(['train', 'test'], [train_imgs, test_imgs]):
        out_dir = os.path.join(OUTPUT_PATH, split_name, cls)
        os.makedirs(out_dir, exist_ok=True)

        for img_path in tqdm(split_data, desc=f"{split_name.capitalize()} - {cls}"):
            try:
                img = cv2.imread(img_path)
                if img is None:
                    continue
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, IMG_SIZE)
                cv2.imwrite(os.path.join(out_dir, os.path.basename(img_path)),
                            cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
            except Exception as e:
                print(f"❌ Error processing {img_path}: {e}")

print("\n✅ Preprocessing Complete!")
print(f"📦 Data saved to: {OUTPUT_PATH}")
# Out:
# Mounted at /content/drive
# 🧹 Deleted existing folder: /content/drive/MyDrive/CapStoneProjectDataSets/Blackgram_split
# 📁 Found Classes: ['Yellow Mosaic 220', 'Leaf Crinckle 150', 'Powdery Mildew 180', 'Healthy 220', 'Anthracnose 230']
#
# 🧾 Processing Class: Yellow Mosaic 220 (224 images)
# Train - Yellow Mosaic 220: 100%|██████████| 179/179 [00:03<00:00, 50.28it/s]
# Test - Yellow Mosaic 220: 100%|██████████| 45/45 [00:00<00:00, 62.69it/s]
# 🧾 Processing Class: Leaf Crinckle 150 (152 images)
# Train - Leaf Crinckle 150: 100%|██████████| 121/121 [00:06<00:00, 19.57it/s]
# Test - Leaf Crinckle 150: 100%|██████████| 31/31 [00:00<00:00, 58.32it/s]
# 🧾 Processing Class: Powdery Mildew 180 (180 images)
# Train - Powdery Mildew 180: 100%|██████████| 144/144 [00:09<00:00, 14.90it/s]
# Test - Powdery Mildew 180: 100%|██████████| 36/36 [00:00<00:00, 60.76it/s]
# 🧾 Processing Class: Healthy 220 (221 images)
# Train - Healthy 220: 100%|██████████| 176/176 [00:07<00:00, 22.73it/s]
# Test - Healthy 220: 100%|██████████| 45/45 [00:00<00:00, 56.64it/s]
# 🧾 Processing Class: Anthracnose 230 (231 images)
# Train - Anthracnose 230: 100%|██████████| 184/184 [00:09<00:00, 20.14it/s]
# Test - Anthracnose 230: 100%|██████████| 47/47 [00:00<00:00, 60.38it/s]
# ✅ Preprocessing Complete!
# 📦 Data saved to: /content/drive/MyDrive/CapStoneProjectDataSets/Blackgram_split

# %%
# ======================================================
# Optimized Hybrid EfficientNetB0 + MobileNetV2 - Blackgram (Target >93%)
# ======================================================

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0, MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Concatenate, Input, BatchNormalization, LeakyReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
import matplotlib.pyplot as plt
import math

# ======================================================
# Paths & Parameters
# ======================================================
BASE_PATH = "/content/drive/MyDrive/CapStoneProjectDataSets/Blackgram_split"
TRAIN_DIR = f"{BASE_PATH}/train"
TEST_DIR  = f"{BASE_PATH}/test"

IMG_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS = 100
INIT_LR = 1e-4

best_model_path  = "/content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras"
final_model_path = "/content/drive/MyDrive/CapStoneProjectDataSets/blackgram_final_model_100epochs.keras"

# ======================================================
# Clean Old Models
# ======================================================
for path in [best_model_path, final_model_path]:
    if os.path.exists(path):
        os.remove(path)
        print(f"🧹 Deleted old model file: {path}")

# ======================================================
# Data Augmentation
# ======================================================
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.4,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.5, 1.5],
    channel_shift_range=20,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

num_classes = len(train_gen.class_indices)
print("\n✅ Detected Classes:", train_gen.class_indices)

# ======================================================
# Hybrid Model Architecture (Enhanced Fine-tuning)
# ======================================================
input_tensor = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# EfficientNetB0
effnet = EfficientNetB0(include_top=False, weights='imagenet', input_tensor=input_tensor)
for layer in effnet.layers[-80:]:  # unfreeze last 80 layers
    layer.trainable = True
effnet_feat = GlobalAveragePooling2D()(effnet.output)

# MobileNetV2
mobilenet = MobileNetV2(include_top=False, weights='imagenet', input_tensor=input_tensor)
for layer in mobilenet.layers[-80:]:
    layer.trainable = True
mobilenet_feat = GlobalAveragePooling2D()(mobilenet.output)

# Combine both features
combined = Concatenate()([effnet_feat, mobilenet_feat])

x = Dense(1024)(combined)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.6)(x)

x = Dense(512)(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.5)(x)

x = Dense(256)(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.4)(x)

output = Dense(num_classes, activation='softmax')(x)
model = Model(inputs=input_tensor, outputs=output)

# ======================================================
# Compile Model with Cosine Annealing LR Schedule
# ======================================================
def cosine_annealing(epoch, total_epochs=EPOCHS, lr_max=INIT_LR, lr_min=1e-6):
    return lr_min + 0.5 * (lr_max - lr_min) * (1 + math.cos(math.pi * epoch / total_epochs))

lr_scheduler = LearningRateScheduler(cosine_annealing, verbose=1)

model.compile(
    optimizer=Adam(INIT_LR),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# ======================================================
# Callbacks
# ======================================================
callbacks = [
    lr_scheduler,
    EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1),
    ModelCheckpoint(best_model_path, monitor='val_accuracy', save_best_only=True, verbose=1)
]

# ======================================================
# Training
# ======================================================
print("\n🚀 Starting Optimized Training (100 Epochs)...")
history = model.fit(
    train_gen,
    validation_data=test_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# ======================================================
# Save Model
# ======================================================
model.save(final_model_path)
print(f"\n✅ Final model saved at: {final_model_path}")

# ======================================================
# Evaluation
# ======================================================
y_true = test_gen.classes
preds = model.predict(test_gen, verbose=0)
y_pred = np.argmax(preds, axis=1)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# Specificity Calculation
spec_list = []
total = np.sum(cm)
for i in range(num_classes):
    TP = cm[i, i]
    FP = np.sum(cm[:, i]) - TP
    FN = np.sum(cm[i, :]) - TP
    TN = total - TP - FP - FN
    spec_list.append(TN / (TN + FP + 1e-7))
spec = np.mean(spec_list)

print("\n📊 === FINAL TEST PERFORMANCE METRICS ===")
print(f"✅ Accuracy: {acc * 100:.2f}%")
print(f"Precision: {prec * 100:.2f}%")
print(f"Recall (Sensitivity): {rec * 100:.2f}%")
print(f"Specificity: {spec * 100:.2f}%")

# ======================================================
# Plot Curves
# ======================================================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc', color='blue')
plt.plot(history.history['val_accuracy'], label='Val Acc', color='orange')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss', color='green')
plt.plot(history.history['val_loss'], label='Val Loss', color='red')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# Mounted at /content/drive
# 🧹 Deleted old model file: /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 🧹 Deleted old model file: /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_final_model_100epochs.keras
# Found 804 images belonging to 5 classes.
# Found 204 images belonging to 5 classes.
#
# ✅ Detected Classes: {'Anthracnose 230': 0, 'Healthy 220': 1, 'Leaf Crinckle 150': 2, 'Powdery Mildew 180': 3, 'Yellow Mosaic 220': 4}
# /tmp/ipython-input-2813729458.py:93: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet = MobileNetV2(include_top=False, weights='imagenet', input_tensor=input_tensor)
# 🚀 Starting Optimized Training (100 Epochs)...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2872 - loss: 1.9192
# Epoch 1: val_accuracy improved from -inf to 0.50490, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.2884 - loss: 1.9149 - val_accuracy: 0.5049 - val_loss: 1.3133 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 9.99999844111277e-05.
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5827 - loss: 1.1553
# Epoch 2: val_accuracy improved from 0.50490 to 0.62745, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - accuracy: 0.5837 - loss: 1.1541 - val_accuracy: 0.6275 - val_loss: 1.1261 - learning_rate: 1.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 9.999715021933996e-05.
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.7620 - loss: 0.9076
# Epoch 3: val_accuracy improved from 0.62745 to 0.69118, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 25s 477ms/step - accuracy: 0.7624 - loss: 0.9075 - val_accuracy: 0.6912 - val_loss: 1.1001 - learning_rate: 9.9997e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 6.0989305746304326e-06.
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.7986 - loss: 0.8305
# Epoch 4: val_accuracy improved from 0.69118 to 0.70588, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 24s 470ms/step - accuracy: 0.7988 - loss: 0.8304 - val_accuracy: 0.7059 - val_loss: 1.1016 - learning_rate: 6.0989e-06
#
# Epoch 5: LearningRateScheduler setting learning rate to 2.212074853988464e-05.
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8036 - loss: 0.8646
# Epoch 5: val_accuracy did not improve from 0.70588
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - accuracy: 0.8039 - loss: 0.8638 - val_accuracy: 0.7059 - val_loss: 1.1097 - learning_rate: 2.2121e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 9.553315373414893e-05.
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8470 - loss: 0.7862
# Epoch 6: val_accuracy improved from 0.70588 to 0.72549, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - accuracy: 0.8471 - loss: 0.7859 - val_accuracy: 0.7255 - val_loss: 1.0580 - learning_rate: 9.5533e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 3.819853096785669e-05.
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8686 - loss: 0.7475
# Epoch 7: val_accuracy improved from 0.72549 to 0.74510, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 460ms/step - accuracy: 0.8686 - loss: 0.7472 - val_accuracy: 0.7451 - val_loss: 0.9886 - learning_rate: 3.8199e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.752791187990604e-06.
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8746 - loss: 0.7251
# Epoch 8: val_accuracy improved from 0.74510 to 0.76471, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 449ms/step - accuracy: 0.8749 - loss: 0.7249 - val_accuracy: 0.7647 - val_loss: 0.9426 - learning_rate: 4.7528e-06
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.906598974414481e-05.
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9015 - loss: 0.6730
# Epoch 9: val_accuracy did not improve from 0.76471
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 36s 349ms/step - accuracy: 0.9013 - loss: 0.6735 - val_accuracy: 0.7500 - val_loss: 0.9927 - learning_rate: 4.9066e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 6.013454709126494e-05.
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8729 - loss: 0.7164
# Epoch 10: val_accuracy improved from 0.76471 to 0.77451, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 435ms/step - accuracy: 0.8729 - loss: 0.7164 - val_accuracy: 0.7745 - val_loss: 0.9289 - learning_rate: 6.0135e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 8.71525988291002e-05.
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8936 - loss: 0.6645
# Epoch 11: val_accuracy improved from 0.77451 to 0.83333, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 451ms/step - accuracy: 0.8937 - loss: 0.6648 - val_accuracy: 0.8333 - val_loss: 0.8257 - learning_rate: 8.7153e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 3.49581228983237e-05.
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8891 - loss: 0.6913
# Epoch 12: val_accuracy did not improve from 0.83333
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 412ms/step - accuracy: 0.8895 - loss: 0.6909 - val_accuracy: 0.8333 - val_loss: 0.8342 - learning_rate: 3.4958e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.43584751722487e-05.
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.8515 - loss: 0.7241
# Epoch 13: val_accuracy did not improve from 0.83333
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 38s 354ms/step - accuracy: 0.8519 - loss: 0.7235 - val_accuracy: 0.7941 - val_loss: 0.9648 - learning_rate: 9.4358e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 5.5340182563504206e-05.
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9000 - loss: 0.6785
# Epoch 14: val_accuracy did not improve from 0.83333
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 358ms/step - accuracy: 0.9002 - loss: 0.6780 - val_accuracy: 0.8137 - val_loss: 0.9363 - learning_rate: 5.5340e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 1.8177413006283977e-05.
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9005 - loss: 0.6524
# Epoch 15: val_accuracy did not improve from 0.83333
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 360ms/step - accuracy: 0.9007 - loss: 0.6524 - val_accuracy: 0.8186 - val_loss: 0.9062 - learning_rate: 1.8177e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.982273622194462e-05.
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9157 - loss: 0.6494
# Epoch 16: val_accuracy did not improve from 0.83333
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 352ms/step - accuracy: 0.9157 - loss: 0.6493 - val_accuracy: 0.8284 - val_loss: 0.9111 - learning_rate: 9.9823e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.590665537101414e-05.
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9093 - loss: 0.6414
# Epoch 17: val_accuracy improved from 0.83333 to 0.84804, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.9093 - loss: 0.6415 - val_accuracy: 0.8480 - val_loss: 0.7970 - learning_rate: 9.5907e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 7.841935891067018e-05.
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9216 - loss: 0.6249
# Epoch 18: val_accuracy did not improve from 0.84804
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 406ms/step - accuracy: 0.9215 - loss: 0.6252 - val_accuracy: 0.8333 - val_loss: 0.8235 - learning_rate: 7.8419e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 6.445658843907899e-06.
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9135 - loss: 0.6485
# Epoch 19: val_accuracy did not improve from 0.84804
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9135 - loss: 0.6483 - val_accuracy: 0.8382 - val_loss: 0.7848 - learning_rate: 6.4457e-06
#
# Epoch 20: LearningRateScheduler setting learning rate to 7.617625961042406e-05.
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9124 - loss: 0.6509
# Epoch 20: val_accuracy improved from 0.84804 to 0.87745, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.9125 - loss: 0.6507 - val_accuracy: 0.8775 - val_loss: 0.7049 - learning_rate: 7.6176e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 1.000016548133931e-06.
# Epoch 21/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9339 - loss: 0.6074
# Epoch 21: val_accuracy did not improve from 0.87745
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 433ms/step - accuracy: 0.9338 - loss: 0.6077 - val_accuracy: 0.8725 - val_loss: 0.6987 - learning_rate: 1.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.971613631117628e-05.
# Epoch 22/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9122 - loss: 0.6483
# Epoch 22: val_accuracy improved from 0.87745 to 0.88235, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - accuracy: 0.9125 - loss: 0.6480 - val_accuracy: 0.8824 - val_loss: 0.7326 - learning_rate: 4.9716e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 8.215389757574635e-05.
# Epoch 23/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9022 - loss: 0.6386
# Epoch 23: val_accuracy improved from 0.88235 to 0.89216, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 24s 469ms/step - accuracy: 0.9022 - loss: 0.6386 - val_accuracy: 0.8922 - val_loss: 0.7566 - learning_rate: 8.2154e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 7.096862782029342e-05.
# Epoch 24/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9205 - loss: 0.6305
# Epoch 24: val_accuracy did not improve from 0.89216
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 433ms/step - accuracy: 0.9204 - loss: 0.6308 - val_accuracy: 0.8873 - val_loss: 0.7386 - learning_rate: 7.0969e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 6.498834167181649e-05.
# Epoch 25/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9570 - loss: 0.5798
# Epoch 25: val_accuracy improved from 0.89216 to 0.89706, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 413ms/step - accuracy: 0.9570 - loss: 0.5799 - val_accuracy: 0.8971 - val_loss: 0.7173 - learning_rate: 6.4988e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 7.060739182076988e-05.
# Epoch 26/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9331 - loss: 0.6260
# Epoch 26: val_accuracy improved from 0.89706 to 0.91667, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 449ms/step - accuracy: 0.9330 - loss: 0.6260 - val_accuracy: 0.9167 - val_loss: 0.6512 - learning_rate: 7.0607e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 3.551782417584985e-05.
# Epoch 27/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9406 - loss: 0.5857
# Epoch 27: val_accuracy did not improve from 0.91667
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - accuracy: 0.9406 - loss: 0.5856 - val_accuracy: 0.9167 - val_loss: 0.6487 - learning_rate: 3.5518e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 8.135160004258581e-05.
# Epoch 28/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9351 - loss: 0.5999
# Epoch 28: val_accuracy did not improve from 0.91667
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 348ms/step - accuracy: 0.9349 - loss: 0.6001 - val_accuracy: 0.8971 - val_loss: 0.6790 - learning_rate: 8.1352e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 1.0390623711978986e-06.
# Epoch 29/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9522 - loss: 0.5871
# Epoch 29: val_accuracy did not improve from 0.91667
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9520 - loss: 0.5872 - val_accuracy: 0.9118 - val_loss: 0.6664 - learning_rate: 1.0391e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 1.785427985985001e-05.
# Epoch 30/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9281 - loss: 0.6193
# Epoch 30: val_accuracy improved from 0.91667 to 0.92647, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - accuracy: 0.9283 - loss: 0.6193 - val_accuracy: 0.9265 - val_loss: 0.6352 - learning_rate: 1.7854e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 3.82857308014472e-05.
# Epoch 31/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9192 - loss: 0.6477
# Epoch 31: val_accuracy improved from 0.92647 to 0.93627, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 24s 467ms/step - accuracy: 0.9196 - loss: 0.6472 - val_accuracy: 0.9363 - val_loss: 0.6320 - learning_rate: 3.8286e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 3.848490294170059e-06.
# Epoch 32/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9577 - loss: 0.5710
# Epoch 32: val_accuracy did not improve from 0.93627
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.9577 - loss: 0.5711 - val_accuracy: 0.9363 - val_loss: 0.6174 - learning_rate: 3.8485e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 4.649774600987416e-05.
# Epoch 33/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9334 - loss: 0.6012
# Epoch 33: val_accuracy did not improve from 0.93627
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 354ms/step - accuracy: 0.9336 - loss: 0.6009 - val_accuracy: 0.9363 - val_loss: 0.6087 - learning_rate: 4.6498e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 9.284698691004167e-05.
# Epoch 34/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9509 - loss: 0.5913
# Epoch 34: val_accuracy did not improve from 0.93627
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 351ms/step - accuracy: 0.9507 - loss: 0.5914 - val_accuracy: 0.9363 - val_loss: 0.6098 - learning_rate: 9.2847e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 9.70317330402158e-05.
# Epoch 35/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9423 - loss: 0.5935
# Epoch 35: val_accuracy did not improve from 0.93627
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 355ms/step - accuracy: 0.9423 - loss: 0.5935 - val_accuracy: 0.9118 - val_loss: 0.6161 - learning_rate: 9.7032e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 1.722070426972385e-05.
# Epoch 36/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9587 - loss: 0.5879
# Epoch 36: val_accuracy improved from 0.93627 to 0.94608, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - accuracy: 0.9584 - loss: 0.5883 - val_accuracy: 0.9461 - val_loss: 0.5840 - learning_rate: 1.7221e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 3.3953063652598337e-06.
# Epoch 37/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9221 - loss: 0.6265
# Epoch 37: val_accuracy did not improve from 0.94608
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 0.9223 - loss: 0.6263 - val_accuracy: 0.9363 - val_loss: 0.5739 - learning_rate: 3.3953e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 8.953748259466717e-06.
# Epoch 38/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9595 - loss: 0.5538
# Epoch 38: val_accuracy did not improve from 0.94608
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 350ms/step - accuracy: 0.9595 - loss: 0.5541 - val_accuracy: 0.9412 - val_loss: 0.5660 - learning_rate: 8.9537e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.0944918569000727e-05.
# Epoch 39/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9496 - loss: 0.5896
# Epoch 39: val_accuracy improved from 0.94608 to 0.95588, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.9496 - loss: 0.5895 - val_accuracy: 0.9559 - val_loss: 0.5499 - learning_rate: 1.0945e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.732232977887013e-05.
# Epoch 40/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9257 - loss: 0.6111
# Epoch 40: val_accuracy did not improve from 0.95588
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9259 - loss: 0.6109 - val_accuracy: 0.9559 - val_loss: 0.5377 - learning_rate: 4.7322e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 2.6031571707457437e-06.
# Epoch 41/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9553 - loss: 0.5699
# Epoch 41: val_accuracy improved from 0.95588 to 0.97059, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 394ms/step - accuracy: 0.9552 - loss: 0.5700 - val_accuracy: 0.9706 - val_loss: 0.5412 - learning_rate: 2.6032e-06
#
# Epoch 42: LearningRateScheduler setting learning rate to 9.768813804270508e-05.
# Epoch 42/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9654 - loss: 0.5723
# Epoch 42: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.9653 - loss: 0.5723 - val_accuracy: 0.9363 - val_loss: 0.5581 - learning_rate: 9.7688e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 6.944210358384932e-05.
# Epoch 43/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9460 - loss: 0.5886
# Epoch 43: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 352ms/step - accuracy: 0.9459 - loss: 0.5888 - val_accuracy: 0.9461 - val_loss: 0.5762 - learning_rate: 6.9442e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 4.722873052998114e-06.
# Epoch 44/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9585 - loss: 0.5543
# Epoch 44: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step - accuracy: 0.9583 - loss: 0.5547 - val_accuracy: 0.9461 - val_loss: 0.5609 - learning_rate: 4.7229e-06
#
# Epoch 45: LearningRateScheduler setting learning rate to 1.4448316610763826e-05.
# Epoch 45/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9107 - loss: 0.6208
# Epoch 45: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - accuracy: 0.9109 - loss: 0.6205 - val_accuracy: 0.9559 - val_loss: 0.5477 - learning_rate: 1.4448e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 8.098014469807972e-05.
# Epoch 46/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9652 - loss: 0.5483
# Epoch 46: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 350ms/step - accuracy: 0.9649 - loss: 0.5487 - val_accuracy: 0.9510 - val_loss: 0.5587 - learning_rate: 8.0980e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 5.1425482636099024e-05.
# Epoch 47/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9607 - loss: 0.5515
# Epoch 47: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - accuracy: 0.9607 - loss: 0.5515 - val_accuracy: 0.9461 - val_loss: 0.5292 - learning_rate: 5.1425e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 8.885724653701969e-05.
# Epoch 48/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9628 - loss: 0.5610
# Epoch 48: val_accuracy did not improve from 0.97059
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 350ms/step - accuracy: 0.9626 - loss: 0.5612 - val_accuracy: 0.9559 - val_loss: 0.5057 - learning_rate: 8.8857e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 8.028023431070404e-05.
# Epoch 49/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9638 - loss: 0.5462
# Epoch 49: val_accuracy improved from 0.97059 to 0.97549, saving model to /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_best_model.keras
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - accuracy: 0.9637 - loss: 0.5466 - val_accuracy: 0.9755 - val_loss: 0.4808 - learning_rate: 8.0280e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 9.973395649271716e-05.
# Epoch 50/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9553 - loss: 0.5905
# Epoch 50: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 402ms/step - accuracy: 0.9553 - loss: 0.5902 - val_accuracy: 0.9559 - val_loss: 0.5075 - learning_rate: 9.9734e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 8.566887536253606e-05.
# Epoch 51/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9570 - loss: 0.5801
# Epoch 51: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 403ms/step - accuracy: 0.9570 - loss: 0.5798 - val_accuracy: 0.9510 - val_loss: 0.5035 - learning_rate: 8.5669e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 3.07162572047334e-05.
# Epoch 52/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9667 - loss: 0.5438
# Epoch 52: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 367ms/step - accuracy: 0.9665 - loss: 0.5440 - val_accuracy: 0.9510 - val_loss: 0.5043 - learning_rate: 3.0716e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 2.2796020382905934e-05.
# Epoch 53/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9756 - loss: 0.5343
# Epoch 53: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - accuracy: 0.9755 - loss: 0.5343 - val_accuracy: 0.9608 - val_loss: 0.4899 - learning_rate: 2.2796e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 7.547868629379545e-06.
# Epoch 54/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9672 - loss: 0.5484
# Epoch 54: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - accuracy: 0.9672 - loss: 0.5484 - val_accuracy: 0.9657 - val_loss: 0.4859 - learning_rate: 7.5479e-06
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.564262259820475e-05.
# Epoch 55/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9451 - loss: 0.5743
# Epoch 55: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - accuracy: 0.9453 - loss: 0.5741 - val_accuracy: 0.9706 - val_loss: 0.4872 - learning_rate: 3.5643e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 6.50616475394033e-05.
# Epoch 56/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9639 - loss: 0.5487
# Epoch 56: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step - accuracy: 0.9639 - loss: 0.5484 - val_accuracy: 0.9755 - val_loss: 0.4681 - learning_rate: 6.5062e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 9.717174548371384e-05.
# Epoch 57/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9736 - loss: 0.5330
# Epoch 57: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 345ms/step - accuracy: 0.9734 - loss: 0.5332 - val_accuracy: 0.9706 - val_loss: 0.4689 - learning_rate: 9.7172e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 8.370364010683869e-05.
# Epoch 58/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9692 - loss: 0.5426
# Epoch 58: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - accuracy: 0.9692 - loss: 0.5425 - val_accuracy: 0.9706 - val_loss: 0.4766 - learning_rate: 8.3704e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 5.562010282128297e-06.
# Epoch 59/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9421 - loss: 0.6113
# Epoch 59: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 362ms/step - accuracy: 0.9424 - loss: 0.6104 - val_accuracy: 0.9755 - val_loss: 0.4706 - learning_rate: 5.5620e-06
#
# Epoch 60: LearningRateScheduler setting learning rate to 3.932989460904108e-05.
# Epoch 60/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9698 - loss: 0.5364
# Epoch 60: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 342ms/step - accuracy: 0.9696 - loss: 0.5365 - val_accuracy: 0.9755 - val_loss: 0.4673 - learning_rate: 3.9330e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 4.279953964776855e-06.
# Epoch 61/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9651 - loss: 0.5350
# Epoch 61: val_accuracy did not improve from 0.97549
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - accuracy: 0.9650 - loss: 0.5351 - val_accuracy: 0.9755 - val_loss: 0.4650 - learning_rate: 4.2800e-06
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 49.
#
# ✅ Final model saved at: /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_final_model_100epochs.keras
#
# 📊 === FINAL TEST PERFORMANCE METRICS ===
# ✅ Accuracy: 97.55%
# Precision: 98.00%
# Recall (Sensitivity): 97.58%
# Specificity: 99.37%

# %%
# ======================================================
# Blackgram Model Testing Script — One Image per Disease with Confidence
# ======================================================

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, ConfusionMatrixDisplay

# ======================================================
# Paths
# ======================================================
BASE_PATH = "/content/drive/MyDrive/CapStoneProjectDataSets/Blackgram_split"
TEST_DIR = f"{BASE_PATH}/test"
MODEL_PATH = "/content/drive/MyDrive/CapStoneProjectDataSets/blackgram_final_model_100epochs.keras"

# ======================================================
# Load Model
# ======================================================
print("📦 Loading trained model...")
model = load_model(MODEL_PATH)
print(f"✅ Model loaded successfully from: {MODEL_PATH}")

# ======================================================
# Test Data Generator
# ======================================================
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

test_datagen = ImageDataGenerator(rescale=1./255)
test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# ======================================================
# Evaluate Entire Test Set
# ======================================================
print("\n🔍 Evaluating model on test dataset...")
preds = model.predict(test_gen, verbose=1)
y_true = test_gen.classes
y_pred = np.argmax(preds, axis=1)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# Specificity
num_classes = len(test_gen.class_indices)
spec_list = []
total = np.sum(cm)
for i in range(num_classes):
    TP = cm[i, i]
    FP = np.sum(cm[:, i]) - TP
    FN = np.sum(cm[i, :]) - TP
    TN = total - TP - FP - FN
    spec_list.append(TN / (TN + FP + 1e-7))
spec = np.mean(spec_list)

print("\n📊 === FINAL BLACKGRAM TEST PERFORMANCE METRICS ===")
print(f"✅ Accuracy: {acc * 100:.2f}%")
print(f"Precision: {prec * 100:.2f}%")
print(f"Recall (Sensitivity): {rec * 100:.2f}%")
print(f"Specificity: {spec * 100:.2f}%")

# ======================================================
# Confusion Matrix
# ======================================================
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(test_gen.class_indices.keys()))
disp.plot(cmap='Greens', xticks_rotation=45)
plt.title("Confusion Matrix - Blackgram Leaf Disease Classification")
plt.show()

# ======================================================
# Display One Image per Class with Confidence
# ======================================================
print("\n🧾 Displaying one image from each disease class with confidence:")

class_labels = list(test_gen.class_indices.keys())
plt.figure(figsize=(15, 6))

for i, class_name in enumerate(class_labels):
    class_dir = os.path.join(TEST_DIR, class_name)
    sample_img = np.random.choice(os.listdir(class_dir))  # Random image from class
    img_path = os.path.join(class_dir, sample_img)

    # Load and preprocess image
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img) / 255.0
    img_batch = np.expand_dims(img_array, axis=0)

    # Predict
    pred_probs = model.predict(img_batch, verbose=0)
    pred_class = np.argmax(pred_probs)
    confidence = np.max(pred_probs) * 100
    pred_label = class_labels[pred_class]

    # Display
    plt.subplot(1, len(class_labels), i + 1)
    plt.imshow(img)
    plt.axis('off')

    color = 'green' if pred_label == class_name else 'red'
    plt.title(f"T: {class_name}\nP: {pred_label}\n({confidence:.1f}%)", color=color, fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# 📦 Loading trained model...
# ✅ Model loaded successfully from: /content/drive/MyDrive/CapStoneProjectDataSets/blackgram_final_model_100epochs.keras
# Found 204 images belonging to 5 classes.
#
# 🔍 Evaluating model on test dataset...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step
#
# 📊 === FINAL BLACKGRAM TEST PERFORMANCE METRICS ===
# ✅ Accuracy: 97.55%
# Precision: 98.00%
# Recall (Sensitivity): 97.58%
# Specificity: 99.37%
# 🧾 Displaying one image from each disease class with confidence:
